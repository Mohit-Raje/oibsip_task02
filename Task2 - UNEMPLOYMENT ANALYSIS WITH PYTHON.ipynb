# %% [markdown]
# ## Oasis infobyte
# ## Data Science Internship Task 2
# ## Mohit Raje
# ## Project : UNEMPLOYMENT ANALYSIS WITH PYTHON

# %% [markdown]
# #### Unemployment is measured by the unemployment rate which is the number of people who are unemployed as a percentage of the total labour force. We have seen a sharp increase in the unemployment rate during Covid-19, so analyzing the unemployment rate can be a good data science project.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing dataset

# %%
df=pd.read_csv("Unemployment_Rate_upto_11_2020.csv")

# %% [markdown]
# ## Data Analysis

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
df['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
print("Total number of regions considered : {}".format(df['Region'].nunique()))
# Out:
# Total number of regions considered : 27

# %%
grpbystate=df.groupby('Region')

# %%
## mean , min  , max , count , sum

# %%
grpbystate.mean()
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_7584\3340292651.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#                    Estimated Unemployment Rate (%)   Estimated Employed  \
# Region
# Andhra Pradesh                            8.664000         1.542548e+07
# Assam                                     4.856000         1.081028e+07
# Bihar                                    19.471000         2.360683e+07
# Chhattisgarh                              7.819000         8.421349e+06
# Delhi                                    18.414000         4.632822e+06
# Goa                                      12.167000         4.423748e+05
# Gujarat                                   6.376000         2.273075e+07
# Haryana                                  27.477000         6.844059e+06
# ...

# %%
grpbystate.max()
# Out:
#                          Date  Frequency   Estimated Unemployment Rate (%)  \
# Region
# Andhra Pradesh     31-10-2020          M                             20.51
# Assam              31-10-2020          M                             11.06
# Bihar              31-10-2020          M                             46.64
# Chhattisgarh       31-10-2020          M                             14.23
# Delhi              31-10-2020          M                             42.27
# Goa                31-10-2020          M                             21.25
# Gujarat            31-10-2020          M                             18.71
# Haryana            31-10-2020          M                             43.22
# Himachal Pradesh   31-10-2020          M                             26.95
# Jammu & Kashmir    31-10-2020          M                             21.08
# Jharkhand          31-10-2020          M                             59.23
# ...

# %%
grpbystate.min()
# Out:
#                          Date  Frequency   Estimated Unemployment Rate (%)  \
# Region
# Andhra Pradesh     29-02-2020          M                              3.31
# Assam              29-02-2020          M                              0.60
# Bihar              29-02-2020          M                              9.82
# Chhattisgarh       29-02-2020          M                              1.96
# Delhi              29-02-2020          M                              6.27
# Goa                29-02-2020          M                              2.81
# Gujarat            29-02-2020          M                              1.84
# Haryana            29-02-2020          M                             19.68
# Himachal Pradesh   29-02-2020          M                              2.20
# Jammu & Kashmir    29-02-2020          M                             10.88
# Jharkhand          29-02-2020          M                              7.63
# ...

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df[df['Region']=="West Bengal"][' Estimated Unemployment Rate (%)'].max()
# Out:
# 17.41

# %%
val=df[' Estimated Unemployment Rate (%)'].max()
df.loc[df[' Estimated Unemployment Rate (%)'] == val, 'Region']
# Out:
# 172    Puducherry
# Name: Region, dtype: object

# %%
val=df[' Estimated Employed'].max()
df.loc[df[' Estimated Employed']==val , 'Region']
# Out:
# 237    Uttar Pradesh
# Name: Region, dtype: object

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
val=df[' Estimated Labour Participation Rate (%)'].max()
df.loc[df[' Estimated Labour Participation Rate (%)']==val , 'Region']
# Out:
# 227    Tripura
# Name: Region, dtype: object

# %%
val=df[' Estimated Labour Participation Rate (%)'].min()
df.loc[df[' Estimated Labour Participation Rate (%)']==val , 'Region']
# Out:
# 122    Kerala
# Name: Region, dtype: object

# %%
df['Region.1'].nunique()
# Out:
# 5

# %%
df['Region.1'].unique()
# Out:
# array(['South', 'Northeast', 'East', 'West', 'North'], dtype=object)

# %%
df.head(1)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
#
#    longitude  latitude
# 0    15.9129     79.74

# %%
grpbyregn=df.groupby('Region.1')

# %%
grpbyregn.max()
# Out:
#                 Region         Date  Frequency  \
# Region.1
# East       West Bengal   31-10-2020          M
# North      Uttarakhand   31-10-2020          M
# Northeast      Tripura   31-10-2020          M
# South        Telangana   31-10-2020          M
# West       Maharashtra   31-10-2020          M
#
#             Estimated Unemployment Rate (%)   Estimated Employed  \
# Region.1
# East                                  59.23             36964178
# North                                 43.22             59433759
# Northeast                             41.23             14107641
# South                                 75.85             27570589
# West                                  21.98             43317881
#
#             Estimated Labour Participation Rate (%)  longitude  latitude
# Region.1
# East                                          47.74    25.0961   87.8550
# North                                         48.25    33.7782   80.9462
# ...

# %%
grpbyregn.min()
# Out:
#                    Region         Date  Frequency  \
# Region.1
# East                Bihar   29-02-2020          M
# North               Delhi   29-02-2020          M
# Northeast           Assam   29-02-2020          M
# South      Andhra Pradesh   29-02-2020          M
# West         Chhattisgarh   29-02-2020          M
#
#             Estimated Unemployment Rate (%)   Estimated Employed  \
# Region.1
# East                                   1.42              4145385
# North                                  2.20              1131128
# Northeast                              0.60               193427
# South                                  0.50               117542
# West                                   1.84               378244
#
#             Estimated Labour Participation Rate (%)  longitude  latitude
# Region.1
# East                                          25.23    20.9517   85.0985
# North                                         19.04    26.8467   74.2179
# ...

# %%
grpbyregn.mean()
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_7584\2759639051.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#             Estimated Unemployment Rate (%)   Estimated Employed  \
# Region.1
# East                              13.916000         1.960237e+07
# North                             15.889620         1.307249e+07
# Northeast                         10.950263         3.617106e+06
# South                             10.454667         1.404059e+07
# West                               8.239000         1.862351e+07
#
#             Estimated Labour Participation Rate (%)  longitude   latitude
# Region.1
# East                                      40.108750  23.161200  85.886625
# North                                     38.702658  29.664871  77.063884
# ...

# %%
df.head(1)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
#
#    longitude  latitude
# 0    15.9129     79.74

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ## Data Visualization

# %%
import plotly.express as px
import plotly

# %%
values=df[' Estimated Unemployment Rate (%)']
category=df['Region']

# %% [markdown]
# ## Pie Charts

# %%
fig=px.pie(df , values = values , names=category , title='Estimated Unemployment Rate (%)')
fig.update_traces(textposition="inside" , textinfo="percent+label")
fig.update_layout(autosize=False,
    width=800,
    height=800,
    title_font_size=20
)

# %%
values=df[' Estimated Employed']
category=df['Region']

# %%
fig=px.pie(df , values = values , names=category , title='Estimated Employed')
fig.update_traces(textposition="inside" , textinfo="percent+label")
fig.update_layout(autosize=False,
    width=800,
    height=800,
    title_font_size=20
)

# %%
values=df[' Estimated Labour Participation Rate (%)']
category=df['Region']

fig=px.pie(df , values=values , names=category  , title='Estimated Labour Participation Rate (%)')
fig.update_layout(
    autosize=False,
    width=800,
    height=800
)

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df['Region.1'].unique()
# Out:
# array(['South', 'Northeast', 'East', 'West', 'North'], dtype=object)

# %% [markdown]
# ## Barplots

# %%
import warnings
warnings.filterwarnings('ignore')
fig , aixs = plt.subplots(figsize=(10, 10))
plt.subplot(2 ,2  ,1)
sns.barplot(x='Region.1' , y=' Estimated Unemployment Rate (%)' , data=df)
plt.subplot(2 , 2 , 2)
sns.barplot(x='Region.1' , y=' Estimated Employed' , data=df)
plt.subplot(2 , 2 , 3)
sns.barplot(x='Region.1' , y=' Estimated Labour Participation Rate (%)' , data=df)
plt.tight_layout()

# %% [markdown]
# ## Countplot

# %%
sns.countplot(x='Region.1' , data=df)
# Out:
# <Axes: xlabel='Region.1', ylabel='count'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Boxplots

# %%
fig , axis = plt.subplots(figsize=(10 , 10))
plt.subplot(2 ,2 ,1)
sns.boxplot(x='Region.1' , y=' Estimated Unemployment Rate (%)' , data=df )
plt.subplot(2 ,2 , 2)
sns.boxplot(x='Region.1' , y=' Estimated Employed' , data=df )
plt.subplot(2 , 2 , 3)
sns.boxplot(x='Region.1' , y=' Estimated Labour Participation Rate (%)' , data=df)
plt.tight_layout()

# %% [markdown]
# ## Swarmplots

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plt.subplot(2 ,2 , 1)
sns.swarmplot(x='Region.1' , y=' Estimated Unemployment Rate (%)' , data=df )
plt.subplot(2,2,2)
sns.swarmplot(x='Region.1' , y=' Estimated Employed' , data=df)
plt.subplot(2 , 2 , 3)
sns.swarmplot(x='Region.1' , y=' Estimated Labour Participation Rate (%)' , data=df)
plt.tight_layout()

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Barplots using plotly

# %%
px.bar(df , x="Region" , y= ' Estimated Unemployment Rate (%)', color="Region.1")

# %%
px.bar(df , x="Region" , y=' Estimated Employed' , color="Region.1")

# %%
px.bar(df , x="Region" , y=' Estimated Labour Participation Rate (%)' , color="Region.1")

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ## Donut Charts

# %%
fig=px.pie(df , names ='Region' ,  values=' Estimated Unemployment Rate (%)' , hole=0.5 , title='Estimated Unemployment Rate (%)')
fig.update_layout(autosize=False , width=800 , height=800)
fig.update_traces(textinfo='percent + label')

# %%
fig=px.pie(df, names='Region' , values=' Estimated Employed' , title='Estimated Employed' , hole=0.5)
fig.update_layout(autosize=False ,width=800 , height=800)

# %%
fig=px.pie(df , names='Region' , values=' Estimated Labour Participation Rate (%)' , hole=0.5 , title='Estimated Labour Participation Rate (%)')
fig.update_layout(autosize=False , width=800 , height=800)

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
fig=px.sunburst(data_frame=df , path=["Region.1" , "Region"])
fig.update_layout(autosize=False , height=800 , width=800)
